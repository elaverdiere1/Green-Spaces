# %%
import pandas as pd
import numpy as np

# %%
inspections = pd.read_csv('Parks_Inspection_Program___Inspections.csv')

# %%
inspections.head()
# Out:
#    Prop ID AMPSDistrict  Inspection ID  Season  Round                    Date  \
# 0    QZ316           06         129809  Winter      6  02/18/2020 12:00:00 AM
# 1  M047-01           11         130016  Spring      1  02/27/2020 12:00:00 AM
# 2    MZ206           10         128568  Winter      5  02/04/2020 12:00:00 AM
# 3    QZ280           03         129814  Winter      6  02/18/2020 12:00:00 AM
# 4    XZ323           04         128541  Winter      5  02/03/2020 12:00:00 AM
#
#   BeginInspection EndInspection  Inspection Year  inspector  inspector2  \
# 0        10:40 AM      10:45 AM             2019         46         NaN
# 1        09:48 AM      10:08 AM             2020         32         NaN
# 2        10:18 AM      10:24 AM             2019         32         NaN
# 3        11:20 AM      11:25 AM             2019         46         NaN
# 4        10:22 AM      10:28 AM             2019         39         NaN
#
# ...

# %%
inspections.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 116512 entries, 0 to 116511
# Data columns (total 20 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Prop ID               116512 non-null  object
#  1   AMPSDistrict          116043 non-null  object
#  2   Inspection ID         116512 non-null  int64
#  3   Season                116512 non-null  object
#  4   Round                 116512 non-null  int64
#  5   Date                  116512 non-null  object
#  6   BeginInspection       116476 non-null  object
#  7   EndInspection         116495 non-null  object
#  8   Inspection Year       116512 non-null  int64
#  9   inspector             116512 non-null  int64
#  10  inspector2            2559 non-null    float64
#  11  Overall Condition     116512 non-null  object
#  12  Cleanliness           116512 non-null  object
#  13  Safety Condition      773 non-null     object
# ...

# %%
inspections['Overall Condition'].value_counts()
# Out:
# A    96780
# U    16353
# N     3379
# Name: Overall Condition, dtype: int64

# %%
inspections.Date = pd.to_datetime(inspections.Date)

# %%
inspections.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 116512 entries, 0 to 116511
# Data columns (total 20 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Prop ID               116512 non-null  object
#  1   AMPSDistrict          116043 non-null  object
#  2   Inspection ID         116512 non-null  int64
#  3   Season                116512 non-null  object
#  4   Round                 116512 non-null  int64
#  5   Date                  116512 non-null  datetime64[ns]
#  6   BeginInspection       116476 non-null  object
#  7   EndInspection         116495 non-null  object
#  8   Inspection Year       116512 non-null  int64
#  9   inspector             116512 non-null  int64
#  10  inspector2            2559 non-null    float64
#  11  Overall Condition     116512 non-null  object
#  12  Cleanliness           116512 non-null  object
#  13  Safety Condition      773 non-null     object
# ...

# %%
inspections['Prop ID'].value_counts()
# Out:
# X118-02      61
# M105-08      60
# M029-ZN03    58
# R070         56
# X051         56
#              ..
# RZ061C        1
# X003          1
# MZ77          1
# B223OA        1
# QZ625         1
# Name: Prop ID, Length: 3945, dtype: int64

# %%
inspections = inspections.loc[inspections.groupby('Prop ID').Date.idxmax(),:]

# %%
inspections.loc[(inspections['Overall Condition'] == 'A') | (inspections['Overall Condition'] == 'U'), :]
# Out:
#       Prop ID AMPSDistrict  Inspection ID  Season  Round       Date  \
# 3226     B001           01         136901    Fall      1 2020-08-31
# 2513     B002           18         133813  Summer      1 2020-06-08
# 2661     B003           19         135802  Summer      4 2020-07-21
# 2477     B006           03         133489  Summer      1 2020-06-01
# 4027     B007           11         136959    Fall      1 2020-09-02
# ...       ...          ...            ...     ...    ...        ...
# 74185    XZ75           02           3575    Fall      3 2000-10-05
# 2516     XZ76           03         133469  Summer      1 2020-06-01
# 3239     XZ79           03         136863    Fall      1 2020-08-28
# 70883    XZ94           04         128421  Winter      4 2020-01-28
# 3285     XZ99           03         136375  Summer      5 2020-08-07
#
#       BeginInspection EndInspection  Inspection Year  inspector  inspector2  \
# ...

# %%
inspections[inspections["Prop ID"].str.contains('X045')]
# Out:
#         Prop ID AMPSDistrict  Inspection ID  Season  Round       Date  \
# 3775    X045-01           01         137307    Fall      2 2020-09-16
# 2803    X045-02           01         135778  Summer      4 2020-07-20
# 4096    X045-03           01         137310    Fall      2 2020-09-16
# 4198  X045-ZN01           01         136919    Fall      1 2020-09-01
# 2640  X045-ZN02           01         134244  Summer      3 2020-07-02
# 3094  X045-ZN03           01         136105  Summer      5 2020-07-30
#
#      BeginInspection EndInspection  Inspection Year  inspector  inspector2  \
# 3775        09:39 AM      10:04 AM             2020         58         NaN
# 2803        11:25 AM      11:35 AM             2020         46         NaN
# 4096        10:14 AM      10:36 AM             2020         58         NaN
# 4198        12:20 PM      01:05 PM             2020         31         NaN
# 2640        08:30 AM      09:17 AM             2020         32         NaN
# ...

# %%
inspections_locations = pd.read_csv('Parks_Inspection_Program___All_Sites.csv')

# %%
inspections_locations
# Out:
#       PropNum    Prop ID Boro AMPSDistrict                  Prop Name  \
# 0        X092       X092    X           13         VAN CORTLANDT PARK
# 1        B018  B018-ZN06    B           18              CANARSIE PARK
# 2        Q470       Q470    Q           01     A.R.R.O.W. Field House
# 3     Q162G10    Q162G10    Q           14                 PARK STRIP
# 4        R065  R065-ZN15    R           02             S.I. GREENBELT
# ...       ...        ...  ...          ...                        ...
# 6424     B126      BR-04    B           04                   Red Hook
# 6425     M353    M353-02    M           14       Riverside Park South
# 6426     X362       X362    X           15  Catherine Scott Promenade
# 6427     R169  R169-ZN01    R           01               Goodhue Park
# 6428     X017       X017    X           05        JULIUS RICHMAN PARK
#
#       Site Name                                      Prop Location  \
# ...

# %%
inspections_locations[inspections_locations['Rated'] == 1]
# Out:
#      PropNum    Prop ID Boro AMPSDistrict                        Prop Name  \
# 1       B018  B018-ZN06    B           18                    CANARSIE PARK
# 4       R065  R065-ZN15    R           02                   S.I. GREENBELT
# 8       X137       X137    X           07                      JEROME PARK
# 9      Q004A      Q004A    Q           01               RALPH DEMARCO PARK
# 12      Q338       Q338    Q           11  Admiral (Sy Seplowe) Playground
# ...      ...        ...  ...          ...                              ...
# 6423    B555       B555    B           04                 Beaver Noll Park
# 6424    B126      BR-04    B           04                         Red Hook
# 6425    M353    M353-02    M           14             Riverside Park South
# 6426    X362       X362    X           15        Catherine Scott Promenade
# 6428    X017       X017    X           05              JULIUS RICHMAN PARK
#
# ...

# %%
inspections_locations.sort_values('Prop ID').head()
# Out:
#      PropNum Prop ID Boro AMPSDistrict                Prop Name  Site Name  \
# 6167    B001    B001    B           01      AMERICAN PLAYGROUND        NaN
# 3654    B002    B002    B           18           AMERSFORT PARK        NaN
# 1428    B003    B003    B           19  BARTEL-PRITCHARD SQUARE        NaN
# 5243    B006    B006    B           03       BEATTIE SQUARE (T)        NaN
# 2046    B007    B007    B           11         BENSONHURST PARK        NaN
#
#                                    Prop Location  \
# 6167                 NOBLE, FRANKLIN, MILTON STS
# 3654                AVE I, 38 & 39TH STS & AVE J
# 1428                    PROSPECT PARK W AT 15 ST
# 5243           BROADWAY, STUYVESANT, VERNON AVES
# 2046  GRAVESEND BAY, 21 & CROPSEY AVES, BAY PKWY
#
#                                    Site Location   Acres    Category  ...  \
# 6167                 Noble, Franklin, Milton Sts   0.896  Small Park  ...
# ...

# %%
inspections_locations['Category'].value_counts()
# Out:
# Greenstreet                     2789
# Small Park                      2084
# Large Park                       853
# Other                            186
# Small Center                      53
# Property                          18
# Large Center                      17
# Playground                         9
# Restrictive Declaration Site       2
# Schoolyard                         1
# Name: Category, dtype: int64

# %%
inspections_final = pd.merge(inspections, inspections_locations, on='Prop ID')

# %%
inspections_final
# Out:
#      Prop ID AMPSDistrict_x  Inspection ID  Season  Round       Date  \
# 0       B001             01         136901    Fall      1 2020-08-31
# 1       B002             18         133813  Summer      1 2020-06-08
# 2       B003             19         135802  Summer      4 2020-07-21
# 3       B006             03         133489  Summer      1 2020-06-01
# 4       B007             11         136959    Fall      1 2020-09-02
# ...      ...            ...            ...     ...    ...        ...
# 3938    XZ94             04         128421  Winter      4 2020-01-28
# 3939    XZ95             04          96732  Spring      6 2015-05-28
# 3940    XZ96             04          98867    Fall      2 2015-09-28
# 3941    XZ97             04          91793  Summer      5 2014-08-19
# 3942    XZ99             03         136375  Summer      5 2020-08-07
#
#      BeginInspection EndInspection  Inspection Year  inspector  ...  \
# 0           11:00 AM      11:25 AM             2020         46  ...
# ...

# %% [markdown]
# Found the most recent inspections and linked the Property ID to a location
